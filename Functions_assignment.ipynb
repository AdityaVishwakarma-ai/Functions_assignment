# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaVishwakarma-ai/Functions_assignment/blob/main/Functions_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fuctions Assignment Solution

# %% [markdown]
# Theory Questions:
#
# 1. What is the difference between a function and a method in Python?
# - Function are reuseable block of code which can be used to save time and make our code visible , whereas a method is what we do generally to solve a problem in programming and we can't reuse it.
#
# 2. Explain the concept of function arguments and parameters in Python.
# - arguments are the actual value you give to the function when you call it.
#    parameters are the palceholder defined whe you define the function.
#
# 3. What are the different ways to define and call a function in Python?
# - using def(function name) we can caal the function
#    also using `return` we can call the value of function. other method are also associated with calling the function name with operators etc.
#
# 4. What is the purpose of the `return` statement in a Python function?
# - `return` statement is used to return the value the function that we have defined.
#
# 5. What are iterators in Python and how do they differ from iterables?
# - Iterators are objects that remember where they are during iteration and give one item at a time using next() we can generate iterable using iter() function, Whereas Iterables are the object we can loop through it and it gives all values at once.
#
# 6. Explain the concept of generators in Python and how they are defined.
# - generators are the special function that return value here we you `yield` instead of `return` and it gives one value at a time and here next is used to get next value.
#
# 7. What are the advantages of using generators over regular functions?
# - we get many advantage for using generators like we can save space and time if we have to find a large output. we can use `yield` fuction to get values one by one.
#
# 8. What is a lambda function in Python and when is it typically used?
# - Lamda function is a short cut function to get any value in a single line of code. using `lamda` fanction.
#
# 9. Explain the purpose and usage of the `map()` function in Python.
# - The map() function is used to apply a function to every item in a list and return a new map object (which is an iterator). It makes code short and clean and without using a loop.
#
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# - map()	Applies a function to each item and reduce() combines the items to a single value and filter() filterout the values based on the condition we  provide.
# reduce() function we import from funtools.
#
# ![WhatsApp Image 2025-05-22 at 20.15.11_fadc1f78.jpg](data:image/jpeg;base64,...)

# %%
# Practical questions

# 1.Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

def sum_even_numbers(numbers):
    even_sum = 0
    for num in numbers:
        if num % 2 == 0:
            even_sum += num
    return even_sum
nums = [10, 5, 8, 3, 2]
result = sum_even_numbers(nums)
print(result)
# Out:
# 20

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string.

def reverse_string(text):
    return text[::-1]
result = reverse_string("hello")
print(result)
# Out:
# olleh

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number

def square_numbers(numbers):
    squared = []
    for num in numbers:
        squared.append(num ** 2)
    return squared
nums = [1, 2, 3, 4]
result = square_numbers(nums)
print(result)
# Out:
# [1, 4, 9, 16]

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

class FibonacciIterator:
    def __init__(self, max_terms):
        self.max_terms = max_terms
        self.count = 0
        self.a = 0
        self.b = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.max_terms:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return 0
        elif self.count == 1:
            self.count += 1
            return 1
        else:
            fib = self.a + self.b
            self.a, self.b = self.b, fib
            self.count += 1
            return fib

n = int(input("Enter number of Fibonacci terms: "))

fib = FibonacciIterator(n)
for num in fib:
    print(num)
# Out:
# Enter number of Fibonacci terms: 5
# 0
# 1
# 1
# 2
# 3
